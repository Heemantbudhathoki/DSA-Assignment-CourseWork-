# %% [markdown]
# Question 2
#
# Scenario: The "Strategic Tile Shatter" Game

# %%
def maxCoins(nums):
    # Add 1 at both ends to handle edges
    balloons = [1] + nums + [1]
    n = len(balloons)

    
    dp = [[0] * n for _ in range(n)]

    
    for length in range(2, n):  
        for i in range(n - length):
            j = i + length
            
            # Try each k in between as last to burst
            for k in range(i + 1, j):
                coins = dp[i][k] + balloons[i] * balloons[k] * balloons[j] + dp[k][j]
                dp[i][j] = max(dp[i][j], coins)

    
    return dp[0][n - 1]

# Example test cases
print(maxCoins([3, 1, 5, 8]))  # Output: 167
print(maxCoins([1, 5]))        # Output: 10
# Out:
# 167
# 10
